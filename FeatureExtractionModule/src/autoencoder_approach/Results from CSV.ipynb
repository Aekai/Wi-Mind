# %% [markdown]
# ###  Imports

# %%
import pandas as pd
import numpy as np
from ast import literal_eval

pd.set_option('display.max_rows', 500)

# %%
column_order = ['dataset used', 'classifier', 'feature used', 'min', 'max', 'median', 'mean']
feature_list = ['phase', 'breathing', 'heartbeat', 'combined br hb', 'undercomplete', 'sparse', 'deep']
results_path = "results/"

# %%
def make_an_aggregated_dataframe(dataset_used, feature_used, accs_dataframe):
    
    # Initialize a dataframe
    return_df = pd.DataFrame()
    
    # Initialize a dictionary
    stats_dict = {}
    stats_dict['dataset used'] = dataset_used
    stats_dict['feature used'] = feature_used
    
    # Loop over all classifiers and 
    for classifier in accs_dataframe.index:
        
        # Extract the accuracies array
        accs_array = np.array(accs_dataframe.loc[classifier])
        
        # Calculate statistics
        stats_dict['classifier'] = classifier
        stats_dict['min'] = np.min(accs_array)
        stats_dict['max'] = np.max(accs_array)
        stats_dict['median'] = np.median(accs_array)
        stats_dict['mean'] = np.mean(accs_array)
#         stats_dict['data_len'] = len(accs_array)
        
        # Append to dataframe
        return_df = return_df.append(stats_dict, ignore_index=True)
    
    return_df = return_df[column_order]
    
    return return_df

# %% [markdown]
# ### Busy vs Relaxed

# %% [markdown]
# What the table should look like (not real data):
#
# | dataset used | classifier | feature used | min | max | median | mean |
# |---|---|---|---|---|---|---|
# | all | LSTM | contractive | 0.2 | 0.8 | 0.56 | 0.6 |
# | NC | dense | phase | 0.4 | 0.7 | 0. 58 | 0.61 |

# %%
BvR_df = pd.DataFrame()
BvR_prefix = "BvR/BvR"
dataset_used_midpoint = "-all"
tfv1_file_ending = "-tfv1"
file_format_ending = ".csv"

# %%
df_all = pd.read_csv(results_path + BvR_prefix + dataset_used_midpoint + file_format_ending, index_col=[0])

for feature_used in feature_list:
    temp_df = df_all[feature_used].apply(literal_eval)
    temp_df = make_an_aggregated_dataframe('all', feature_used, temp_df)
    BvR_df = BvR_df.append(temp_df, ignore_index=True)

# %%
df_all_tfv1 = pd.read_csv(results_path + BvR_prefix + dataset_used_midpoint + tfv1_file_ending + file_format_ending, index_col=[0])
temp_df = df_all_tfv1['contractive'].apply(literal_eval)
temp_df = make_an_aggregated_dataframe('all', 'contractive', temp_df)
BvR_df = BvR_df.append(temp_df, ignore_index=True)

# %%
BvR_prefix = "BvR/BvR"
dataset_used_midpoint = "-NC"
tfv1_file_ending = "-tfv1"
file_format_ending = ".csv"

# %%
df_NC = pd.read_csv(results_path + BvR_prefix + dataset_used_midpoint + file_format_ending, index_col=[0])

for feature_used in feature_list:
    temp_df = df_NC[feature_used].apply(literal_eval)
    temp_df = make_an_aggregated_dataframe('NC', feature_used, temp_df)
    BvR_df = BvR_df.append(temp_df, ignore_index=True)

# %%
df_NC_tfv1 = pd.read_csv(results_path + BvR_prefix + dataset_used_midpoint + tfv1_file_ending + file_format_ending, index_col=[0])
temp_df = df_NC_tfv1['contractive'].apply(literal_eval)
temp_df = make_an_aggregated_dataframe('NC', 'contractive', temp_df)
BvR_df = BvR_df.append(temp_df, ignore_index=True)

# %%
BvR_df.sort_values(['dataset used', 'classifier'], ascending=[True,True], inplace=True)
BvR_df
# Out:
#     dataset used      classifier    feature used       min       max  \
# 57            NC            LSTM           phase  0.250000  1.000000
# 64            NC            LSTM       breathing  0.333333  1.000000
# 71            NC            LSTM       heartbeat  0.000000  0.833333
# 78            NC            LSTM  combined br hb  0.333333  1.000000
# 85            NC            LSTM   undercomplete  0.250000  1.000000
# 92            NC            LSTM          sparse  0.166667  0.833333
# 99            NC            LSTM            deep  0.166667  1.000000
# 106           NC            LSTM     contractive  0.166667  0.833333
# 59            NC             SVC           phase  0.333333  1.000000
# 66            NC             SVC       breathing  0.333333  1.000000
# 73            NC             SVC       heartbeat  0.000000  0.833333
# 80            NC             SVC  combined br hb  0.250000  1.000000
# 87            NC             SVC   undercomplete  0.333333  1.000000
# 94            NC             SVC          sparse  0.166667  0.833333
# 101           NC             SVC            deep  0.333333  1.000000
# 108           NC             SVC     contractive  0.500000  1.000000
# 62            NC         XGBoost           phase  0.000000  0.833333
# 69            NC         XGBoost       breathing  0.166667  1.000000
# 76            NC         XGBoost       heartbeat  0.166667  0.833333
# 83            NC         XGBoost  combined br hb  0.166667  1.000000
# 90            NC         XGBoost   undercomplete  0.000000  0.833333
# 97            NC         XGBoost          sparse  0.166667  1.000000
# 104           NC         XGBoost            deep  0.000000  0.833333
# 111           NC         XGBoost     contractive  0.500000  1.000000
# 58            NC             kNN           phase  0.333333  0.833333
# 65            NC             kNN       breathing  0.166667  1.000000
# 72            NC             kNN       heartbeat  0.250000  0.833333
# 79            NC             kNN  combined br hb  0.500000  1.000000
# 86            NC             kNN   undercomplete  0.333333  1.000000
# 93            NC             kNN          sparse  0.166667  1.000000
# 100           NC             kNN            deep  0.166667  1.000000
# 107           NC             kNN     contractive  0.333333  1.000000
# 61            NC  naive_bayesian           phase  0.166667  1.000000
# 68            NC  naive_bayesian       breathing  0.250000  1.000000
# 75            NC  naive_bayesian       heartbeat  0.000000  1.000000
# 82            NC  naive_bayesian  combined br hb  0.250000  1.000000
# 89            NC  naive_bayesian   undercomplete  0.333333  0.833333
# 96            NC  naive_bayesian          sparse  0.166667  1.000000
# 103           NC  naive_bayesian            deep  0.333333  1.000000
# 110           NC  naive_bayesian     contractive  0.333333  1.000000
# 60            NC   random_forest           phase  0.333333  1.000000
# 67            NC   random_forest       breathing  0.166667  1.000000
# 74            NC   random_forest       heartbeat  0.166667  0.833333
# 81            NC   random_forest  combined br hb  0.166667  1.000000
# 88            NC   random_forest   undercomplete  0.166667  1.000000
# 95            NC   random_forest          sparse  0.166667  1.000000
# 102           NC   random_forest            deep  0.166667  1.000000
# 109           NC   random_forest     contractive  0.333333  1.000000
# 56            NC    simple_dense           phase  0.333333  0.833333
# 63            NC    simple_dense       breathing  0.250000  1.000000
# 70            NC    simple_dense       heartbeat  0.166667  1.000000
# 77            NC    simple_dense  combined br hb  0.250000  1.000000
# 84            NC    simple_dense   undercomplete  0.333333  1.000000
# 91            NC    simple_dense          sparse  0.333333  1.000000
# 98            NC    simple_dense            deep  0.333333  1.000000
# 105           NC    simple_dense     contractive  0.500000  1.000000
# 1            all            LSTM           phase  0.433333  0.972222
# 8            all            LSTM       breathing  0.437500  0.941176
# 15           all            LSTM       heartbeat  0.312500  0.666667
# 22           all            LSTM  combined br hb  0.416667  0.861111
# 29           all            LSTM   undercomplete  0.433333  0.750000
# 36           all            LSTM          sparse  0.343750  0.718750
# 43           all            LSTM            deep  0.441176  0.882353
# 50           all            LSTM     contractive  0.400000  0.781250
# 3            all             SVC           phase  0.375000  0.750000
# 10           all             SVC       breathing  0.500000  0.888889
# 17           all             SVC       heartbeat  0.300000  0.700000
# 24           all             SVC  combined br hb  0.468750  0.916667
# 31           all             SVC   undercomplete  0.437500  0.888889
# 38           all             SVC          sparse  0.433333  0.750000
# 45           all             SVC            deep  0.400000  0.687500
# 52           all             SVC     contractive  0.441176  0.781250
# 6            all         XGBoost           phase  0.437500  0.794118
# 13           all         XGBoost       breathing  0.437500  0.888889
# 20           all         XGBoost       heartbeat  0.406250  0.633333
# 27           all         XGBoost  combined br hb  0.343750  0.866667
# 34           all         XGBoost   undercomplete  0.472222  0.718750
# 41           all         XGBoost          sparse  0.500000  0.805556
# 48           all         XGBoost            deep  0.444444  0.722222
# 55           all         XGBoost     contractive  0.466667  0.781250
# 2            all             kNN           phase  0.416667  0.800000
# 9            all             kNN       breathing  0.500000  0.944444
# 16           all             kNN       heartbeat  0.352941  0.700000
# 23           all             kNN  combined br hb  0.375000  0.916667
# 30           all             kNN   undercomplete  0.444444  0.666667
# 37           all             kNN          sparse  0.406250  0.852941
# 44           all             kNN            deep  0.433333  0.781250
# 51           all             kNN     contractive  0.375000  0.843750
# 5            all  naive_bayesian           phase  0.411765  0.687500
# 12           all  naive_bayesian       breathing  0.333333  0.944444
# 19           all  naive_bayesian       heartbeat  0.233333  0.687500
# 26           all  naive_bayesian  combined br hb  0.375000  0.900000
# 33           all  naive_bayesian   undercomplete  0.323529  0.588235
# 40           all  naive_bayesian          sparse  0.437500  0.722222
# 47           all  naive_bayesian            deep  0.382353  0.666667
# 54           all  naive_bayesian     contractive  0.466667  0.791667
# 4            all   random_forest           phase  0.531250  0.823529
# 11           all   random_forest       breathing  0.468750  0.900000
# 18           all   random_forest       heartbeat  0.352941  0.625000
# 25           all   random_forest  combined br hb  0.406250  0.888889
# 32           all   random_forest   undercomplete  0.472222  0.833333
# 39           all   random_forest          sparse  0.466667  0.916667
# 46           all   random_forest            deep  0.406250  0.766667
# 53           all   random_forest     contractive  0.466667  0.852941
# 0            all    simple_dense           phase  0.400000  0.852941
# 7            all    simple_dense       breathing  0.466667  0.866667
# 14           all    simple_dense       heartbeat  0.388889  0.750000
# 21           all    simple_dense  combined br hb  0.312500  0.906250
# 28           all    simple_dense   undercomplete  0.437500  0.777778
# 35           all    simple_dense          sparse  0.333333  0.812500
# 42           all    simple_dense            deep  0.400000  0.781250
# 49           all    simple_dense     contractive  0.468750  0.843750
#
#        median      mean
# 57   0.833333  0.713768
# 64   0.666667  0.666667
# 71   0.500000  0.528986
# 78   0.666667  0.695652
# 85   0.500000  0.576087
# 92   0.500000  0.481884
# 99   0.666667  0.594203
# 106  0.500000  0.565217
# 59   0.666667  0.655797
# 66   0.666667  0.717391
# 73   0.500000  0.528986
# 80   0.666667  0.692029
# 87   0.666667  0.659420
# 94   0.666667  0.586957
# 101  0.500000  0.554348
# 108  0.666667  0.764493
# 62   0.666667  0.572464
# 69   0.833333  0.739130
# 76   0.500000  0.514493
# 83   0.833333  0.753623
# 90   0.666667  0.586957
# 97   0.666667  0.615942
# 104  0.500000  0.474638
# 111  0.666667  0.739130
# 58   0.666667  0.630435
# 65   0.666667  0.692029
# 72   0.500000  0.496377
# 79   0.666667  0.746377
# 86   0.500000  0.586957
# 93   0.500000  0.543478
# 100  0.500000  0.532609
# 107  0.666667  0.713768
# 61   0.500000  0.507246
# 68   0.666667  0.670290
# 75   0.500000  0.514493
# 82   0.666667  0.677536
# 89   0.500000  0.579710
# 96   0.500000  0.557971
# 103  0.500000  0.565217
# 110  0.666667  0.699275
# 60   0.666667  0.623188
# 67   0.833333  0.739130
# 74   0.500000  0.557971
# 81   0.833333  0.746377
# 88   0.666667  0.670290
# 95   0.666667  0.590580
# 102  0.500000  0.496377
# 109  0.666667  0.713768
# 56   0.666667  0.615942
# 63   0.666667  0.677536
# 70   0.500000  0.554348
# 77   0.666667  0.699275
# 84   0.666667  0.670290
# 91   0.666667  0.663043
# 98   0.666667  0.673913
# 105  0.833333  0.764493
# 1    0.676471  0.652334
# 8    0.633333  0.650927
# 15   0.500000  0.499062
# 22   0.617647  0.629634
# 29   0.558824  0.573160
# 36   0.583333  0.577597
# 43   0.583333  0.582777
# 50   0.562500  0.558946
# 3    0.617647  0.612727
# 10   0.656250  0.678254
# 17   0.529412  0.523549
# 24   0.647059  0.666743
# 31   0.588235  0.592675
# 38   0.625000  0.611802
# 45   0.558824  0.548092
# 52   0.625000  0.613440
# 6    0.638889  0.634925
# 13   0.656250  0.674616
# 20   0.500000  0.514246
# 27   0.676471  0.676551
# 34   0.593750  0.602259
# 41   0.593750  0.605953
# 48   0.566667  0.570943
# 55   0.593750  0.596812
# 2    0.625000  0.630818
# 9    0.687500  0.694190
# 16   0.531250  0.530483
# 23   0.625000  0.643936
# 30   0.600000  0.579508
# 37   0.633333  0.629962
# 44   0.593750  0.598991
# 51   0.617647  0.612779
# 5    0.500000  0.528009
# 12   0.647059  0.630190
# 19   0.531250  0.522119
# 26   0.566667  0.611333
# 33   0.470588  0.466624
# 40   0.562500  0.558783
# 47   0.529412  0.530717
# 54   0.588235  0.586555
# 4    0.647059  0.656694
# 11   0.700000  0.699488
# 18   0.527778  0.506250
# 25   0.676471  0.685910
# 32   0.566667  0.596089
# 39   0.676471  0.636756
# 46   0.593750  0.596512
# 53   0.617647  0.633657
# 0    0.617647  0.599529
# 7    0.687500  0.675627
# 14   0.558824  0.543111
# 21   0.625000  0.655877
# 28   0.593750  0.607442
# 35   0.647059  0.643999
# 42   0.555556  0.566029
# 49   0.656250  0.642279

# %%
BvR_df.loc[BvR_df['classifier'] == 'LSTM']
# Out:
#     dataset used classifier    feature used       min       max    median  \
# 57            NC       LSTM           phase  0.250000  1.000000  0.833333
# 64            NC       LSTM       breathing  0.333333  1.000000  0.666667
# 71            NC       LSTM       heartbeat  0.000000  0.833333  0.500000
# 78            NC       LSTM  combined br hb  0.333333  1.000000  0.666667
# 85            NC       LSTM   undercomplete  0.250000  1.000000  0.500000
# 92            NC       LSTM          sparse  0.166667  0.833333  0.500000
# 99            NC       LSTM            deep  0.166667  1.000000  0.666667
# 106           NC       LSTM     contractive  0.166667  0.833333  0.500000
# 1            all       LSTM           phase  0.433333  0.972222  0.676471
# 8            all       LSTM       breathing  0.437500  0.941176  0.633333
# 15           all       LSTM       heartbeat  0.312500  0.666667  0.500000
# 22           all       LSTM  combined br hb  0.416667  0.861111  0.617647
# 29           all       LSTM   undercomplete  0.433333  0.750000  0.558824
# 36           all       LSTM          sparse  0.343750  0.718750  0.583333
# 43           all       LSTM            deep  0.441176  0.882353  0.583333
# 50           all       LSTM     contractive  0.400000  0.781250  0.562500
#
#          mean
# 57   0.713768
# 64   0.666667
# 71   0.528986
# 78   0.695652
# 85   0.576087
# 92   0.481884
# 99   0.594203
# 106  0.565217
# 1    0.652334
# 8    0.650927
# 15   0.499062
# 22   0.629634
# 29   0.573160
# 36   0.577597
# 43   0.582777
# 50   0.558946

# %%
BvR_df.to_csv(results_path + "BvR.csv", mode='w', index=False)
